# %%
import os
print(os.getcwd())
# Out:
# /home/jovyan

# %%
import pandas as pd
import matploitlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import matploitlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'
